# %%
import matplotlib.pyplot as plt
marks = [10,25,35,45,55]
subjects = ["java","aws","xl","sql","python"]
plt.figure(figsize=(6,6))
explode = [0, 0, 0.2, 0,0]
plt.pie(marks,
labels= subjects,
colors = ["red","green","blue","yellow","pink"],
autopct="%1.1f%%",
pctdistance=0.7,
labeldistance=1.2,
normalize=True,
rotatelabels=True,
explode=explode,
shadow

)
       

plt.title("Student Skills")
plt.show()
