# %%
print("hello ")
# Out:
# hello

# %%
name = input("enter the name:")
print("my name is:",name)
# Out:
# enter the name: yusuf
# my name is: yusuf

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
sum = num1 + num2
print("sum=", sum)
# Out:
# Enter first number:  2
# Enter second number:  2
# sum= 4

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

difference = num1 - num2

print("Difference =", difference)
# Out:
# Enter first number:  2
# Enter second number:  2
# Difference = 0

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Before Swap")
print("a =", a)
print("b =", b)

a, b = b, a

print("After Swap")
print("a =", a)
print("b =", b)
# Out:
# Enter first number:  2
# Enter second number:  2
# Before Swap
# a = 2
# b = 2
# After Swap
# a = 2
# b = 2

# %%
num = int(input("Enter a number: "))

square = num ** 2

print("Square =", square)
# Out:
# Enter a number:  2
# Square = 4

# %%
num = int(input("Enter a number: "))

cube = num ** 3

print("Cube =", cube)
# Out:
# Enter a number:  3
# Cube = 27

# %%
import math

radius = float(input("Enter radius: "))

area = math.pi * radius ** 2

print("Area of Circle =", area)
# Out:
# Enter radius:  2
# Area of Circle = 12.566370614359172

# %%
a = 10
b = 20

print("Sum =", a + b)
# Out:
# Sum = 30

# %%
num = 5

print("Square =", num ** 2)
# Out:
# Square = 25

# %%
name = input("Enter Student Name: ")
roll_no = int(input("Enter Roll Number: "))
course = input("Enter Course: ")
marks = float(input("Enter Marks: "))

print("\n------ Student Details ------")
print("Name :", name)
print("Roll No :", roll_no)
print("Course :", course)
print("Marks :", marks)
# Out:
# Enter Student Name:  yusuf
# Enter Roll Number:  101
# Enter Course:  ai
# Enter Marks:  1000
# ------ Student Details ------
# Name : yusuf
# Roll No : 101
# Course : ai
# Marks : 1000.0

# %%
num1 = float(input("Enter First Number: "))
num2 = float(input("Enter Second Number: "))

print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter Choice: "))

if choice == 1:
    print("Result =", num1 + num2)
elif choice == 2:
    print("Result =", num1 - num2)
elif choice == 3:
    print("Result =", num1 * num2)
elif choice == 4:
    if num2 != 0:
        print("Result =", num1 / num2)
    else:
        print("Cannot divide by zero")
else:
    print("Invalid Choice")
# Out:
# Enter First Number:  10
# Enter Second Number:  -20
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter Choice:  2
# Result = 30.0

# %%
units = int(input("Enter Units Consumed: "))

if units <= 100:
    bill = units * 2
elif units <= 200:
    bill = (100 * 2) + ((units - 100) * 3)
else:
    bill = (100 * 2) + (100 * 3) + ((units - 200) * 5)

print("Electricity Bill =", bill)
# Out:
# Enter Units Consumed:  150
# Electricity Bill = 350

# %%
name = input("Enter Employee Name: ")
basic_salary = float(input("Enter Basic Salary: "))

hra = basic_salary * 0.20
da = basic_salary * 0.10
gross_salary = basic_salary + hra + da

print("\nEmployee Name :", name)
print("Basic Salary :", basic_salary)
print("HRA :", hra)
print("DA :", da)
print("Gross Salary :", gross_salary)
# Out:
# Enter Employee Name:  yusuf
# Enter Basic Salary:  12000
# Employee Name : yusuf
# Basic Salary : 12000.0
# HRA : 2400.0
# DA : 1200.0
# Gross Salary : 15600.0

# %%
balance = 5000
print("1. Check Balance")
print("2. Deposit")
print("3. Withdraw")
choice = int(input("enter choice:"))
if choice ==1:
    print("avilable balance=",balance)
elif choice ==2:
    amount = float(input("enter the amount:"))
    balance += amount
    print("update balance=", balance)
elif choice ==3:
    amount = float(input("enter the amount:"))
    if amount <=balance:
        balance -=amount
        print("update balance =",balance)
    else:
        print("insufficienet balance")
else:
    print("invalid choice")
# Out:
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# enter choice: 3
# enter the amount: 3000
# update balance = 2000.0

# %%
celsius = float(input("Enter Temperature in Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit =", fahrenheit)
# Out:
# Enter Temperature in Celsius:  46
# Temperature in Fahrenheit = 114.8

# %%
celsius = float(input("Enter Temperature in Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit =", fahrenheit)
# Out:
# Enter Temperature in Celsius:  24
# Temperature in Fahrenheit = 75.2

# %%
weight = float(input("Enter Weight (kg): "))
height = float(input("Enter Height (m): "))

bmi = weight / (height ** 2)



if bmi < 18.5:
    print("Underweight")
elif bmi < 25:
    print("Normal Weight")
elif bmi < 30:
    print("Overweight")
else:
    print("Obese")
# Out:
# Enter Weight (kg):  60
# Enter Height (m):  140
# Underweight

# %%
m1 = int(input("Enter Subject 1 Marks: "))
m2 = int(input("Enter Subject 2 Marks: "))
m3 = int(input("Enter Subject 3 Marks: "))
m4 = int(input("Enter Subject 4 Marks: "))
m5 = int(input("Enter Subject 5 Marks: "))

total = m1 + m2 + m3 + m4 + m5
percentage = total / 5

print("Total =", total)
print("Percentage =", percentage)

if percentage >= 90:
    print("Grade : A")
elif percentage >= 75:
    print("Grade : B")
elif percentage >= 60:
    print("Grade : C")
elif percentage >= 40:
    print("Grade : D")
else:
    print("Fail")
# Out:
# Enter Subject 1 Marks:  10
# Enter Subject 2 Marks:  23
# Enter Subject 3 Marks:  35
# Enter Subject 4 Marks:  56
# Enter Subject 5 Marks:  6
# Total = 130
# Percentage = 26.0
# Fail

# %%
item = input("Enter Item Name: ")
price = float(input("Enter Item Price: "))
quantity = int(input("Enter Quantity: "))

total = price * quantity

print("\nItem :", item)
print("Price :", price)
print("Quantity :", quantity)
print("Total Bill =", total)
# Out:
# Enter Item Name:  dal
# Enter Item Price:  166
# Enter Quantity:  2
# Item : dal
# Price : 166.0
# Quantity : 2
# Total Bill = 332.0

# %%
birth_year = int(input("Enter Birth Year: "))
current_year = int(input("Enter Current Year: "))

age = current_year - birth_year

print("Your Age is", age, "Years")
# Out:
# Enter Birth Year:  2003
# Enter Current Year:  2026
# Your Age is 23 Years

# %%
from datetime import date


birth_date = date(2003, 1, 4)
today = date.today()

age = today.year - birth_date.year

if (today.month, today.day) < (birth_date.month, birth_date.day):
    age -= 1

print("Date of Birth :", birth_date)
print("Today's Date  :", today)
print("Age :", age, "years")
# Out:
# Date of Birth : 2003-01-04
# Today's Date  : 2026-06-30
# Age : 23 years

# %%
s1 = input("First String: ")
s2 = input("Second String: ")

if sorted(s1) == sorted(s2):
    print("Anagram")
else:
    print("Not Anagram")
# Out:
# First String:  yusuf
# Second String:  shaik
# Not Anagram

# %%
numbers = [10,20,8,30,40,99] 
largest = numbers[0]
for num in numbers:
    if num > largest:
        largest = num
print(largest)
# Out:
# 99

# %%
numbers = [-5,10,20,30,40,50,77,99,-10]
first = float('-inf')
second = float('-inf')
for num in numbers:
    if num > first:
        second = first
        first = num
       
    elif num > second and num !=first:
        second = num
print("first_largest:",first)
print("second_largest:",second)
# Out:
# first_largest: 99
# second_largest: 77

# %%
text = "python"
reverse =""
for ch in text:
    reverse = ch + reverse
print(reverse)
# Out:
# nohtyp

# %%
text = "yusuf"
reverse =""
for ch in text:
    reverse = ch + reverse
print(reverse)
# Out:
# fusuy

# %%
text = "flashman"
reverse = ""
for ch in text:
    reverse = ch + reverse
if text == reverse:
    print("palidrom")
else:
    print("not palidrom")
# Out:
# not palidrom

# %%
text = ""
reverse = ""
for ch in text:
    reverse = ch + reverse
if text == reverse:
    print("palidrom")
else:
    print("not palidrom")
# Out:
# palidrom

# %%
text = "pythonprgraming"
repeat ={}
for ch in text:
    if ch in repeat:
        repeat[ch] = repeat[ch] +1
    else:
        repeat[ch]=1
print(repeat)
# Out:
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 2, 'r': 2, 'g': 2, 'a': 1, 'm': 1, 'i': 1}

# %%
words = "pythonprogramingsqlscript"
repeat = {}
for ch in words:
    if ch in repeat:
        repeat[ch] =repeat[ch]+1
    else:
        repeat[ch]=1
print(repeat)
# Out:
# {'p': 3, 'y': 1, 't': 2, 'h': 1, 'o': 2, 'n': 2, 'r': 3, 'g': 2, 'a': 1, 'm': 1, 'i': 2, 's': 2, 'q': 1, 'l': 1, 'c': 1}

# %%
num1 = int(input())
num2 = int(input())

if num1 == num2:
    print("equal")
else:
    sum = num1 + num2
    print(sum)
# Out:
#  2
#  4
# 6
